# %%
# 파이썬 라이브러리 호출
from urllib.parse import urlencode, unquote
import requests
import json
import pandas as pd
import math
import numpy as np

# %%
# 인증키
encoding ='XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3%2BmExZwQ%3D%3D'
decoding ='XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=='

# %%
url ='http://apis.data.go.kr/1160100/service/GetFinaStatInfoService/getSummFinaStat'

# %%
# 하나씩 불러오기
# queryString
empty2 =pd.DataFrame()
queryString = "?"+urlencode(
{
    "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
      "pageNo":'1',
"numOfRows":"10",
"resultType":"json",
 "bizYear" :"2021"
}
)
queryURL = url + queryString
response = requests.get(queryURL)
r_dict = json.loads(response.text)
doc = r_dict["response"]["body"]["items"]["item"]
df =pd.DataFrame(doc)
empty2 = empty.append(df)

# %%
empty2
# Out:
#       basDt           crno bizYear                  fnclDcd fnclDcdNm  \
# 0  20211231  0000000000000    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 1  20211108  0004108280449    2021                      999        NA
# 2  20211231  1101110000086    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 3  20211231  1101110000086    2021      ifrs_SeparateMember  별도요약재무제표
# 4  20211231  1101110002404    2021                      120  요약별도재무정보
# 5  20211231  1101110002694    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 6  20211231  1101110002694    2021      ifrs_SeparateMember  별도요약재무제표
# 7  20211231  1101110002959    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 8  20211231  1101110002959    2021      ifrs_SeparateMember  별도요약재무제표
# 9  20211231  1101110003098    2021  ifrs_ConsolidatedMember  연결요약재무제표
#
#        enpSaleAmt     enpBzopPft  iclsPalClcAmt     enpCrtmNpf  \
# 0       686721451       16649554       31640370        3441877
# 1   1090216000000              0              0    50381000000
# ...

# %%
r_dict
# Out:
# {'response': {'body': {'items': {'item': []},
#    'numOfRows': 10,
#    'pageNo': 11207,
#    'totalCount': 112052},
#   'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}}}

# %%
queryURL = url + queryString

# %%
response = requests.get(queryURL)

# %%
# json 값 가져오기
# data = requests.get(queryURL).json()
data = response.json()

# %%
print(data)
# Out:
# {'response': {'body': {'items': {'item': [{'basDt': '20211231', 'crno': '1101114806993', 'bizYear': '2021', 'fnclDcd': '120', 'fnclDcdNm': '요약별도재무정보', 'enpSaleAmt': '1584926000', 'enpBzopPft': '-603105000', 'iclsPalClcAmt': '-597318000', 'enpCrtmNpf': '-597413000', 'enpTastAmt': '1376936000', 'enpTdbtAmt': '1943012000', 'enpTcptAmt': '-566076000', 'enpCptlAmt': '50000000', 'fnclDebtRto': '-343.2422501572'}, {'basDt': '20211231', 'crno': '1101114807157', 'bizYear': '2021', 'fnclDcd': '110', 'fnclDcdNm': '요약연결재무제표', 'enpSaleAmt': '1335000000', 'enpBzopPft': '65000000', 'iclsPalClcAmt': '93000000', 'enpCrtmNpf': '93000000', 'enpTastAmt': '342000000', 'enpTdbtAmt': '843000000', 'enpTcptAmt': '-501000000', 'enpCptlAmt': '50000000', 'fnclDebtRto': '0'}, {'basDt': '20211231', 'crno': '1101114807363', 'bizYear': '2021', 'fnclDcd': '110', 'fnclDcdNm': '요약연결재무제표', 'enpSaleAmt': '1129000000', 'enpBzopPft': '-439000000', 'iclsPalClcAmt': '-486000000', 'enpCrtmNpf': '-486000000', 'enpTastAmt': '4
# ...

# %%
r_dict = json.loads(response.text)

# %%
print(r_dict)
# Out:
# {'response': {'body': {'items': {'item': [{'basDt': '19990212', 'crno': '1101110223563', 'bizYear': '1999', 'fnclDcd': '999', 'fnclDcdNm': 'NA', 'enpSaleAmt': '80365000000', 'enpBzopPft': '0', 'iclsPalClcAmt': '0', 'enpCrtmNpf': '3207000000', 'enpTastAmt': '252512000000', 'enpTdbtAmt': '205225000000', 'enpTcptAmt': '252512000000', 'enpCptlAmt': '10900000000', 'fnclDebtRto': '0'}]}, 'numOfRows': 1, 'pageNo': 1, 'totalCount': 1545053}, 'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}}}

# %%
doc = r_dict["response"]["body"]["items"]["item"]
print(doc)
# Out:
# [{'basDt': '19991210', 'crno': '1101110223563', 'bizYear': '1999', 'fnclDcd': '999', 'fnclDcdNm': 'NA', 'enpSaleAmt': '80365000000', 'enpBzopPft': '0', 'iclsPalClcAmt': '0', 'enpCrtmNpf': '3207000000', 'enpTastAmt': '252512000000', 'enpTdbtAmt': '205225000000', 'enpTcptAmt': '252512000000', 'enpCptlAmt': '10900000000', 'fnclDebtRto': '0'}]

# %%
empty_df = pd.DataFrame()
df=pd.concat([empty_df,pd.DataFrame(doc)],axis =0)
df
# Out:
#       basDt           crno bizYear fnclDcd fnclDcdNm   enpSaleAmt enpBzopPft  \
# 0  19991210  1101110223563    1999     999        NA  80365000000          0
#
#   iclsPalClcAmt  enpCrtmNpf    enpTastAmt    enpTdbtAmt    enpTcptAmt  \
# 0             0  3207000000  252512000000  205225000000  252512000000
#
#     enpCptlAmt fnclDebtRto
# 0  10900000000           0

# %%
r_dict = json.loads(response.text)
numOfRows = r_dict["response"]["body"]["numOfRows"]

# %%
totCnt = r_dict["response"]["body"]["totalCount"]
loopCount = math.ceil(totCnt/numOfRows)
print(loopCount)
# Out:
# 11206

# %%
# 여러 개 불러오기
empty = pd.DataFrame()
error =[]
for number in range(1,1001):
  queryString = "?"+urlencode(
    {       
            "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
                "pageNo": number,
            "numOfRows":"10",
            "resultType":"json",
            "bizYear":"2021"
    }
  )
  queryURL =url +queryString
  try:
    response = requests.get(queryURL)
    r_dict = json.loads(response.text)
    doc = r_dict["response"]["body"]["items"]["item"]
    df = pd.DataFrame(doc)
    empty = empty.append(df)
  except Exception as e:
    print("오류 발생 : ",e)
    print("오류 number : ",number)
    error.append(number)

# 마지막 오류 834

# 1545083 * 10
# Out:
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  973

# %%
error
# Out:
# [973]

# %%
# error들로 만들기
df_error =pd.DataFrame()
for i in error:
  queryString = "?"+urlencode(
  {
      "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
        "pageNo":i,
  "numOfRows":"10",
  "resultType":"json",
  "bizYear" :"2021"
  }
  )
  queryURL = url + queryString
  response = requests.get(queryURL)
  r_dict = json.loads(response.text)
  doc = r_dict["response"]["body"]["items"]["item"]

# %%
df_error = pd.DataFrame(doc)
df_error
# Out:
#       basDt           crno bizYear fnclDcd fnclDcdNm   enpSaleAmt  enpBzopPft  \
# 0  20211231  1101112776966    2021     120  요약별도재무정보  14531746000    -5718000
# 1  20211231  1101112777865    2021     120  요약별도재무정보    646898000  -110608000
# 2  20211231  1101112778037    2021     120  요약별도재무정보   1081358000    12033000
# 3  20211231  1101112778087    2021     120  요약별도재무정보   9407915000   236077000
# 4  20211231  1101112778293    2021     120  요약별도재무정보     40000000   -69433000
# 5  20211231  1101112778368    2021     120  요약별도재무정보     18825000   -80588000
# 6  20211231  1101112778491    2021     110  요약연결재무제표   7939000000   -86000000
# 7  20211231  1101112779001    2021     110  요약연결재무제표   1490000000    54000000
# 8  20211231  1101112779134    2021     110  요약연결재무제표  37353000000  2392000000
# 9  20211231  1101112779514    2021     120  요약별도재무정보   4075207000   335723000
#
#   iclsPalClcAmt  enpCrtmNpf  enpTastAmt  enpTdbtAmt  enpTcptAmt enpCptlAmt  \
# ...

# %%
# 합치기 1 ~1000
df_1 = pd.concat([empty,df_error],axis = 0)
df_1
# Out:
#        basDt           crno bizYear                  fnclDcd fnclDcdNm  \
# 0   20211231  0000000000000    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 1   20211108  0004108280449    2021                      999        NA
# 2   20211231  1101110000086    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 3   20211231  1101110000086    2021      ifrs_SeparateMember  별도요약재무제표
# 4   20211231  1101110002404    2021                      120  요약별도재무정보
# ..       ...            ...     ...                      ...       ...
# 5   20211231  1101112778368    2021                      120  요약별도재무정보
# 6   20211231  1101112778491    2021                      110  요약연결재무제표
# 7   20211231  1101112779001    2021                      110  요약연결재무제표
# 8   20211231  1101112779134    2021                      110  요약연결재무제표
# 9   20211231  1101112779514    2021                      120  요약별도재무정보
#
#         enpSaleAmt    enpBzopPft  iclsPalClcAmt     enpCrtmNpf  \
# ...

# %%
# 교차검증용
queryString = "?"+urlencode(
{
    "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
      "pageNo":'578',
"numOfRows":"10",
"resultType":"json",
 "bizYear" :"2021"
}
)
queryURL = url + queryString
response = requests.get(queryURL)
r_dict = json.loads(response.text)
doc = r_dict["response"]["body"]["items"]["item"]
# Out:
#       basDt           crno bizYear fnclDcd fnclDcdNm   enpSaleAmt  enpBzopPft  \
# 0  20211231  1101111718167    2021     120  요약별도재무정보    589186000    33754000
# 1  20211231  1101111718191    2021     120  요약별도재무정보  12926303000   771287000
# 2  20211231  1101111718331    2021     120  요약별도재무정보            0   -33654000
# 3  20211231  1101111718349    2021     110  요약연결재무제표   1397000000    35000000
# 4  20211231  1101111718373    2021     120  요약별도재무정보   4572236000   820817000
# 5  20211231  1101111718604    2021     120  요약별도재무정보  13429110000   404585000
# 6  20211231  1101111718779    2021     120  요약별도재무정보    730521000      341000
# 7  20211231  1101111718787    2021     120  요약별도재무정보  17815198000   420774000
# 8  20211231  1101111719032    2021     120  요약별도재무정보    823433000   -16335000
# 9  20211231  1101111720112    2021     120  요약별도재무정보   1267637000  -853766000
#
#   iclsPalClcAmt  enpCrtmNpf   enpTastAmt   enpTdbtAmt  enpTcptAmt enpCptlAmt  \
# ...

# %%
# 2000번
empty_2 = pd.DataFrame()
error =[]
for number in range(1001,2001):
  queryString = "?"+urlencode(
    {       
            "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
                "pageNo": number,
            "numOfRows":"10",
            "resultType":"json",
            "bizYear":"2021"
    }
  )
  queryURL =url +queryString
  try:
    response = requests.get(queryURL)
    r_dict = json.loads(response.text)
    doc = r_dict["response"]["body"]["items"]["item"]
    df = pd.DataFrame(doc)
    empty_2 = empty_2.append(df)
  except Exception as e:
    print("오류 발생 : ",e)
    print("오류 number : ",number)
    error.append(number)
# Out:
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1525
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1527
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1528
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1548
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1549
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1557
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1559
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1562
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1563
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1565
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1567
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1573
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  1574
# ...

# %%
df_error =pd.DataFrame()
for i in error:
  queryString = "?"+urlencode(
  {
      "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
        "pageNo":i,
  "numOfRows":"10",
  "resultType":"json",
  "bizYear" :"2021"
  }
  )
  queryURL = url + queryString
  response = requests.get(queryURL)
  r_dict = json.loads(response.text)
  doc = r_dict["response"]["body"]["items"]["item"]
  df_error =pd.concat([df_error,pd.DataFrame(doc)],axis = 0)

# %%
df_error
# Out:
#        basDt           crno bizYear                  fnclDcd fnclDcdNm  \
# 0   20211231  1101114178491    2021                      120  요약별도재무정보
# 1   20211231  1101114178847    2021                      120  요약별도재무정보
# 2   20211231  1101114179291    2021                      120  요약별도재무정보
# 3   20211231  1101114179457    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 4   20211231  1101114179457    2021      ifrs_SeparateMember  별도요약재무제표
# ..       ...            ...     ...                      ...       ...
# 5   20211231  1101114665266    2021                      110  요약연결재무제표
# 6   20211231  1101114665357    2021                      120  요약별도재무정보
# 7   20211231  1101114665547    2021                      120  요약별도재무정보
# 8   20211231  1101114665597    2021                      110  요약연결재무제표
# 9   20211231  1101114666438    2021                      110  요약연결재무제표
#
#      enpSaleAmt   enpBzopPft iclsPalClcAmt    enpCrtmNpf   enpTastAmt  \
# ...

# %%
df_2 = pd.concat([empty_2, df_error],axis = 0)
df_2
# Out:
#        basDt           crno bizYear fnclDcd fnclDcdNm   enpSaleAmt  \
# 0   20211231  1101112860842    2021     120  요약별도재무정보   4464051000
# 1   20211231  1101112860925    2021     110  요약연결재무제표  88515000000
# 2   20211231  1101112861113    2021     120  요약별도재무정보   3192834000
# 3   20211231  1101112861741    2021     120  요약별도재무정보   1083789000
# 4   20211231  1101112861791    2021     110  요약연결재무제표   5170000000
# ..       ...            ...     ...     ...       ...          ...
# 5   20211231  1101114665266    2021     110  요약연결재무제표   1317000000
# 6   20211231  1101114665357    2021     120  요약별도재무정보   2572035000
# 7   20211231  1101114665547    2021     120  요약별도재무정보   2609025000
# 8   20211231  1101114665597    2021     110  요약연결재무제표   2020000000
# 9   20211231  1101114666438    2021     110  요약연결재무제표  11144000000
#
#      enpBzopPft iclsPalClcAmt   enpCrtmNpf   enpTastAmt   enpTdbtAmt  \
# 0      62311000      70214000     63193000   1684715000    260968000
# ...

# %%
# 3000번
empty_3 = pd.DataFrame()
error =[]
for number in range(2001,3001):
  queryString = "?"+urlencode(
    {       
            "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
                "pageNo": number,
            "numOfRows":"10",
            "resultType":"json",
            "bizYear":"2021"
    }
  )
  queryURL =url +queryString
  try:
    response = requests.get(queryURL)
    r_dict = json.loads(response.text)
    doc = r_dict["response"]["body"]["items"]["item"]
    df = pd.DataFrame(doc)
    empty_3 = empty_3.append(df)
  except Exception as e:
    print("오류 발생 : ",e)
    print("오류 number : ",number)
    error.append(number)

# %%
empty_3
df_3 = empty_3

# %%
# 3000번 ~ 5000
empty_4 = pd.DataFrame()
error =[]
for number in range(3001,5001):
  queryString = "?"+urlencode(
    {       
            "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
                "pageNo": number,
            "numOfRows":"10",
            "resultType":"json",
            "bizYear":"2021"
    }
  )
  queryURL =url +queryString
  try:
    response = requests.get(queryURL)
    r_dict = json.loads(response.text)
    doc = r_dict["response"]["body"]["items"]["item"]
    df = pd.DataFrame(doc)
    empty_4 = empty_4.append(df)
  except Exception as e:
    print("오류 발생 : ",e)
    print("오류 number : ",number)
    error.append(number)
# Out:
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  3879
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  3881
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  4784
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  4785
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  4807

# %%
df_4 = empty_4

# %%
# error 넣기
# error들로 만들기
df_error =pd.DataFrame()
for i in error:
  queryString = "?"+urlencode(
  {
      "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
        "pageNo":i,
  "numOfRows":"10",
  "resultType":"json",
  "bizYear" :"2021"
  }
  )
  queryURL = url + queryString
  response = requests.get(queryURL)
  r_dict = json.loads(response.text)
  doc = r_dict["response"]["body"]["items"]["item"]
  df_error =pd.concat([df_error,pd.DataFrame(doc)],axis = 0) # axis = 0 행 기준으로 합침, axis =1 열 기준으로 합침

# %%
df_4 = pd.concat([df_4, df_error],axis = 0)
df_4
# Out:
#        basDt           crno bizYear fnclDcd fnclDcdNm   enpSaleAmt  \
# 0   20210430  1101117855103    2021     120  요약별도재무정보            0
# 1   20211231  1101117855301    2021     120  요약별도재무정보  29574834000
# 2   20211231  1101117855947    2021     110  요약연결재무제표    405000000
# 3   20211231  1101117856250    2021     110  요약연결재무제표    247000000
# 4   20211231  1101117857589    2021     110  요약연결재무제표    792000000
# ..       ...            ...     ...     ...       ...          ...
# 5   20211231  1314110347156    2021     120  요약별도재무정보  14380691000
# 6   20211231  1314110347297    2021     120  요약별도재무정보   1636956000
# 7   20211231  1314110347891    2021     120  요약별도재무정보   1701053000
# 8   20211231  1314110347958    2021     120  요약별도재무정보    756534000
# 9   20211231  1314110348013    2021     120  요약별도재무정보    352523000
#
#      enpBzopPft iclsPalClcAmt   enpCrtmNpf   enpTastAmt   enpTdbtAmt  \
# 0             0             0            0     55507000     26012000
# ...

# %%
# 5000 ~ 7000
empty_5 = pd.DataFrame()
error =[]
for number in range(5001,7001):
  queryString = "?"+urlencode(
    {       
            "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
                "pageNo": number,
            "numOfRows":"10",
            "resultType":"json",
            "bizYear":"2021"
    }
  )
  queryURL =url +queryString
  try:
    response = requests.get(queryURL)
    r_dict = json.loads(response.text)
    doc = r_dict["response"]["body"]["items"]["item"]
    df = pd.DataFrame(doc)
    empty_5 = empty_5.append(df)
  except Exception as e:
    print("오류 발생 : ",e)
    print("오류 number : ",number)
    error.append(number)
# Out:
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5002
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5003
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5004
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5009
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5015
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5018
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5021
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5024
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5041
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5043
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5046
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5048
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  5051
# ...

# %%
error
len(error)
# Out:
# 50

# %%
empty_5
# Out:
#        basDt           crno bizYear fnclDcd fnclDcdNm   enpSaleAmt  \
# 0   20211231  1341110208898    2021     120  요약별도재무정보   3192878000
# 1   20211231  1341110209002    2021     120  요약별도재무정보    872179000
# 2   20211231  1341110209028    2021     120  요약별도재무정보   1410155000
# 3   20211231  1341110209317    2021     110  요약연결재무제표   3406000000
# 4   20211231  1341110209862    2021     110  요약연결재무제표  43787000000
# ..       ...            ...     ...     ...       ...          ...
# 5   20211231  1544110033732    2021     120  요약별도재무정보   1443916000
# 6   20211231  1544110034277    2021     120  요약별도재무정보   4864284000
# 7   20211231  1544110034615    2021     120  요약별도재무정보   2571917000
# 8   20211231  1544110034665    2021     120  요약별도재무정보   1001115000
# 9   20211231  1544110034756    2021     110  요약연결재무제표    782000000
#
#     enpBzopPft iclsPalClcAmt  enpCrtmNpf   enpTastAmt  enpTdbtAmt  enpTcptAmt  \
# 0    132902000     134495000   134495000   2446038000  1331629000  1114409000
# ...

# %%
# 5000 ~ 7000 에러
df_error =pd.DataFrame()
for i in error:
  queryString = "?"+urlencode(
  {
      "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
        "pageNo":i,
  "numOfRows":"10",
  "resultType":"json",
  "bizYear" :"2021"
  }
  )
  queryURL = url + queryString
  response = requests.get(queryURL)
  r_dict = json.loads(response.text)
  doc = r_dict["response"]["body"]["items"]["item"]
  df_error =pd.concat([df_error,pd.DataFrame(doc)],axis = 0)

# %%
df_5 = pd.concat([empty_5, df_error],axis =0)
df_5
# Out:
#        basDt           crno bizYear fnclDcd fnclDcdNm   enpSaleAmt  \
# 0   20211231  1341110208898    2021     120  요약별도재무정보   3192878000
# 1   20211231  1341110209002    2021     120  요약별도재무정보    872179000
# 2   20211231  1341110209028    2021     120  요약별도재무정보   1410155000
# 3   20211231  1341110209317    2021     110  요약연결재무제표   3406000000
# 4   20211231  1341110209862    2021     110  요약연결재무제표  43787000000
# ..       ...            ...     ...     ...       ...          ...
# 5   20211231  1355110359577    2021     120  요약별도재무정보   1605838000
# 6   20211231  1355110359692    2021     120  요약별도재무정보   5526679000
# 7   20211231  1355110359791    2021     120  요약별도재무정보    339614000
# 8   20211231  1355110360053    2021     120  요약별도재무정보    499937000
# 9   20211231  1355110360326    2021     120  요약별도재무정보    880638000
#
#     enpBzopPft iclsPalClcAmt  enpCrtmNpf   enpTastAmt  enpTdbtAmt  enpTcptAmt  \
# 0    132902000     134495000   134495000   2446038000  1331629000  1114409000
# ...

# %%
# 7000 ~ 9000
empty_6 = pd.DataFrame()
error =[]
for number in range(7001,9001):
  queryString = "?"+urlencode(
    {       
            "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
                "pageNo": number,
            "numOfRows":"10",
            "resultType":"json",
            "bizYear":"2021"
    }
  )
  queryURL =url +queryString
  try:
    response = requests.get(queryURL)
    r_dict = json.loads(response.text)
    doc = r_dict["response"]["body"]["items"]["item"]
    df = pd.DataFrame(doc)
    empty_6 = empty_6.append(df)
  except Exception as e:
    print("오류 발생 : ",e)
    print("오류 number : ",number)
    error.append(number)
# Out:
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  7262
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  7264
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  7265
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  7266
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  8171

# %%
df_error =pd.DataFrame()
for i in error:
  queryString = "?"+urlencode(
  {
      "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
        "pageNo":i,
  "numOfRows":"10",
  "resultType":"json",
  "bizYear" :"2021"
  }
  )
  queryURL = url + queryString
  response = requests.get(queryURL)
  r_dict = json.loads(response.text)
  doc = r_dict["response"]["body"]["items"]["item"]
  df_error =pd.concat([df_error,pd.DataFrame(doc)],axis = 0)

# %%
df_6 = pd.concat([empty_6,df_error],axis = 0)

# %%
df_6
# Out:
#        basDt           crno bizYear fnclDcd fnclDcdNm  enpSaleAmt  enpBzopPft  \
# 0   20211231  1544110036851    2021     120  요약별도재무정보   651736000    14016000
# 1   20211231  1544110037833    2021     120  요약별도재무정보   993499000    87626000
# 2   20211231  1544110038063    2021     110  요약연결재무제표   556000000     7000000
# 3   20211231  1544110038352    2021     110  요약연결재무제표           0   -73000000
# 4   20211231  1544110039342    2021     110  요약연결재무제표           0   -60000000
# ..       ...            ...     ...     ...       ...         ...         ...
# 5   20211231  1743110000763    2021     120  요약별도재무정보  8025553000   248871000
# 6   20211231  1743110000797    2021     110  요약연결재무제표  2006000000    95000000
# 7   20211231  1743110001167    2021     110  요약연결재무제표  1616000000  -487000000
# 8   20211231  1743110001349    2021     110  요약연결재무제표  2259000000    45000000
# 9   20211231  1743110001589    2021     110  요약연결재무제표  6952000000  -324000000
#
# ...

# %%
# 변수에 따른 값을 부여, global()[이름]
for i in range(1,6):
  globals()['var_{0}'.format(i)] =i

# %%
df_list = [df_1,df_2,df_3,df_4,df_5,df_6]
save_1 =pd.concat(df_list,ignore_index =True)

# %%
save_1
# Out:
#           basDt           crno bizYear                  fnclDcd fnclDcdNm  \
# 0      20211231  0000000000000    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 1      20211108  0004108280449    2021                      999        NA
# 2      20211231  1101110000086    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 3      20211231  1101110000086    2021      ifrs_SeparateMember  별도요약재무제표
# 4      20211231  1101110002404    2021                      120  요약별도재무정보
# ...         ...            ...     ...                      ...       ...
# 89995  20211231  1743110000763    2021                      120  요약별도재무정보
# 89996  20211231  1743110000797    2021                      110  요약연결재무제표
# 89997  20211231  1743110001167    2021                      110  요약연결재무제표
# 89998  20211231  1743110001349    2021                      110  요약연결재무제표
# 89999  20211231  1743110001589    2021                      110  요약연결재무제표
#
#            enpSaleAmt    enpBzopPft  iclsPalClcAmt     enpCrtmNpf  \
# ...

# %%
save_1.to_csv("save_1.csv")

# %%
# 9000 ~ 11000
empty_6 = pd.DataFrame()
error =[]
for number in range(9001,11001):
  queryString = "?"+urlencode(
    {       
            "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
                "pageNo": number,
            "numOfRows":"10",
            "resultType":"json",
            "bizYear":"2021"
    }
  )
  queryURL =url +queryString
  try:
    response = requests.get(queryURL)
    r_dict = json.loads(response.text)
    doc = r_dict["response"]["body"]["items"]["item"]
    df = pd.DataFrame(doc)
    empty_6 = empty_6.append(df)
  except Exception as e:
    print("오류 발생 : ",e)
    print("오류 number : ",number)
    error.append(number)
# Out:
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  9092
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  10851
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  10853
# 오류 발생 :  Expecting value: line 1 column 1 (char 0)
# 오류 number :  10869

# %%
error
# Out:
# [9092, 10851, 10853, 10869]

# %%
df_error =pd.DataFrame()
for i in error:
  queryString = "?"+urlencode(
  {
      "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
        "pageNo":i,
  "numOfRows":"10",
  "resultType":"json",
  "bizYear" :"2021"
  }
  )
  queryURL = url + queryString
  response = requests.get(queryURL)
  r_dict = json.loads(response.text)
  doc = r_dict["response"]["body"]["items"]["item"]
  df_error =pd.concat([df_error,pd.DataFrame(doc)],axis = 0)

# %%
empty_6
# Out:
#        basDt           crno bizYear fnclDcd fnclDcdNm   enpSaleAmt  \
# 0   20211231  1801111118579    2021     120  요약별도재무정보   2615278000
# 1   20211231  1801111118727    2021     120  요약별도재무정보  41826188000
# 2   20211231  1801111118751    2021     120  요약별도재무정보   2165072000
# 3   20211231  1801111119048    2021     110  요약연결재무제표   4286000000
# 4   20211231  1801111119064    2021     120  요약별도재무정보   3124000000
# ..       ...            ...     ...     ...       ...          ...
# 5   20211231  2849110146489    2021     120  요약별도재무정보  12835123000
# 6   20211231  2849110146497    2021     120  요약별도재무정보    837640000
# 7   20211231  2849110146611    2021     120  요약별도재무정보   5240054000
# 8   20211231  2849110146918    2021     110  요약연결재무제표   2218000000
# 9   20211231  2849110147007    2021     120  요약별도재무정보   3441407000
#
#     enpBzopPft iclsPalClcAmt  enpCrtmNpf  enpTastAmt  enpTdbtAmt   enpTcptAmt  \
# 0   -561235000    -579190000  -579190000  1096653000  3372820000  -2276167000
# ...

# %%
df_7 = pd.concat([empty_6,df_error],axis = 0)
df_7
# Out:
#        basDt           crno bizYear fnclDcd fnclDcdNm   enpSaleAmt  \
# 0   20211231  1801111118579    2021     120  요약별도재무정보   2615278000
# 1   20211231  1801111118727    2021     120  요약별도재무정보  41826188000
# 2   20211231  1801111118751    2021     120  요약별도재무정보   2165072000
# 3   20211231  1801111119048    2021     110  요약연결재무제표   4286000000
# 4   20211231  1801111119064    2021     120  요약별도재무정보   3124000000
# ..       ...            ...     ...     ...       ...          ...
# 5   20211231  2842110064180    2021     110  요약연결재무제표   9693000000
# 6   20211231  2842110064370    2021     120  요약별도재무정보  13007723000
# 7   20211231  2842110064908    2021     110  요약연결재무제표   7622000000
# 8   20211231  2842110065542    2021     110  요약연결재무제표  12647000000
# 9   20211231  2842110065568    2021     120  요약별도재무정보     59753000
#
#     enpBzopPft iclsPalClcAmt  enpCrtmNpf   enpTastAmt  enpTdbtAmt  \
# 0   -561235000    -579190000  -579190000   1096653000  3372820000
# ...

# %%
empty_8 = pd.DataFrame()
error =[]
for number in range(11001,11207):
  queryString = "?"+urlencode(
    {       
            "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
                "pageNo": number,
            "numOfRows":"10",
            "resultType":"json",
            "bizYear":"2021"
    }
  )
  queryURL =url +queryString
  try:
    response = requests.get(queryURL)
    r_dict = json.loads(response.text)
    doc = r_dict["response"]["body"]["items"]["item"]
    df = pd.DataFrame(doc)
    empty_8 = empty_8.append(df)
  except Exception as e:
    print("오류 발생 : ",e)
    print("오류 number : ",number)
    error.append(number)

# %%
df_error =pd.DataFrame()
for i in error:
  queryString = "?"+urlencode(
  {
      "serviceKey":unquote("XmfiH3nZQaeyXUgpfyj0gIMZVKgMHhJp4bErJEN7Bc3ObVkDLBT3Z3pD4Fzj3wcxzDmdEUIsbDqclA3+mExZwQ=="),
        "pageNo":i,
  "numOfRows":"10",
  "resultType":"json",
  "bizYear" :"2021"
  }
  )
  queryURL = url + queryString
  response = requests.get(queryURL)
  r_dict = json.loads(response.text)
  doc = r_dict["response"]["body"]["items"]["item"]
  df_error =pd.concat([df_error,pd.DataFrame(doc)],axis = 0)

# %%
df_8=empty_8
df_8
# Out:
#        basDt           crno bizYear fnclDcd fnclDcdNm     enpSaleAmt  \
# 0   20211231  2849110147130    2021     110  요약연결재무제표     2135000000
# 1   20211231  2849110147346    2021     120  요약별도재무정보     3334184000
# 2   20211231  2849110147560    2021     120  요약별도재무정보     7662175000
# 3   20211231  2849110147776    2021     120  요약별도재무정보     8373051000
# 4   20211231  2849110147859    2021     120  요약별도재무정보     3060388000
# ..       ...            ...     ...     ...       ...            ...
# 7   20210222  5503111058116    2021     999        NA   196765000000
# 8   20210629  9991438269831    2021     999        NA  1442069000000
# 9   20210702  9991438269831    2021     999        NA  1442069000000
# 0   20210222  9994078269389    2021     999        NA   196765000000
# 1   20210325  9995068034198    2021     999        NA    95834000000
#
#     enpBzopPft iclsPalClcAmt   enpCrtmNpf     enpTastAmt    enpTdbtAmt  \
# ...

# %%
data_list_2 =[save_1,df_7,df_8]
FinalData = pd.concat(data_list_2,ignore_index = True)

# %%
FinalData
# Out:
#            basDt           crno bizYear                  fnclDcd fnclDcdNm  \
# 0       20211231  0000000000000    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 1       20211108  0004108280449    2021                      999        NA
# 2       20211231  1101110000086    2021  ifrs_ConsolidatedMember  연결요약재무제표
# 3       20211231  1101110000086    2021      ifrs_SeparateMember  별도요약재무제표
# 4       20211231  1101110002404    2021                      120  요약별도재무정보
# ...          ...            ...     ...                      ...       ...
# 112047  20210222  5503111058116    2021                      999        NA
# 112048  20210629  9991438269831    2021                      999        NA
# 112049  20210702  9991438269831    2021                      999        NA
# 112050  20210222  9994078269389    2021                      999        NA
# 112051  20210325  9995068034198    2021                      999        NA
#
# ...

# %%
names= ['기준일자','법인등록번호','사업연도','재무제표구분코드','재무제표구분코드명','기업매출금액','기업영업이익','포괄손익계산금액','기업당기순이익','기업총자산금액','기업총부채금액','기업총자본금액','기업자본금액','재무제표부채비율']

# %%
names= ['기준일자','법인등록번호','사업연도','재무제표구분코드','재무제표구분코드명','기업매출금액','기업영업이익','포괄손익계산금액','기업당기순이익','기업총자산금액','기업총부채금액','기업총자본금액',\
        '기업자본금액','재무제표부채비율']

# %%
FinalData.columns =names

# %%
FinalData_2021 = FinalData

# %%
# 요약재무재표 조회
# 금융위원회_기업
FinalData_2021


FinalData_2021.to_csv("FinalData_2021.csv")

# %%
FinalData_2021
# Out:
#             기준일자         법인등록번호  사업연도                 재무제표구분코드 재무제표구분코드명  \
# 0       20211231  0000000000000  2021  ifrs_ConsolidatedMember  연결요약재무제표
# 1       20211108  0004108280449  2021                      999        NA
# 2       20211231  1101110000086  2021  ifrs_ConsolidatedMember  연결요약재무제표
# 3       20211231  1101110000086  2021      ifrs_SeparateMember  별도요약재무제표
# 4       20211231  1101110002404  2021                      120  요약별도재무정보
# ...          ...            ...   ...                      ...       ...
# 112047  20210222  5503111058116  2021                      999        NA
# 112048  20210629  9991438269831  2021                      999        NA
# 112049  20210702  9991438269831  2021                      999        NA
# 112050  20210222  9994078269389  2021                      999        NA
# 112051  20210325  9995068034198  2021                      999        NA
#
#                 기업매출금액        기업영업이익       포괄손익계산금액        기업당기순이익  \
# ...

# %%
FinalData_2021.to_excel('FinalData_2021.xlsx')
